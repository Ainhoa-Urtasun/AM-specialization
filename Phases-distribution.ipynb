# %%
import pandas
import matplotlib.pyplot as plt

# %% [markdown]
# ## Terms in phases

# %%
df1 = pandas.read_csv('D:/BG/Paper_2/analyses-2/Labelling/Predictions-all.csv')
print(df1['Predicted Phases'].value_counts())
df1
# Out:
# Support Activities            4402
# Software                      4054
# Tooling and Machining         1224
# Materials                      785
# Supply Chain and Logistics     678
# Design                         327
# Production and Assembling      241
# Ideation and Development       168
# General Skills                 137
# Name: Predicted Phases, dtype: int64
#        SkillId               Skill_US  IsSpecialized  IsSoftware  IsBaseline  \
# 0            1                     na              0           0           0
# 1            3      anxiety reduction              1           0           0
# 2            5             injections              1           0           0
# 3           11  hm customs and excise              1           0           0
# 4           12      behavioral health              1           0           0
# ...        ...                    ...            ...         ...         ...
# 12011    18031                  latex              1           1           0
# 12012    18034         rapid recovery              1           0           0
# 12013    18035       react javascript              1           1           0
# 12014    18036   virtual reality (vr)              1           0           0
# 12015  9000069      behavior problems              1           0           0
#
#        IsLanguage  IsActive                                    SkillCluster  \
# 0               0         1                                              na
# 1               0         1        mental and behavioral health specialties
# 2               0         1                                blood collection
# 3               0         1                                              na
# 4               0         1        mental and behavioral health specialties
# ...           ...       ...                                             ...
# 12011           0         1                            typesetting software
# 12012           0         1                system design and implementation
# 12013           0         1                           javascript and jquery
# 12014           0         1  augumented reality / virtual reality (ar / vr)
# 12015           0         1        mental and behavioral health specialties
#
#            SkillClusterFamily    Phases    Predicted Phases
# 0                          na       NaN            Software
# 1                 health care       NaN  Support Activities
# 2                 health care       NaN            Software
# 3                          na       NaN  Support Activities
# 4                 health care       NaN  Support Activities
# ...                       ...       ...                 ...
# 12011  information technology  Software            Software
# 12012  information technology  Software            Software
# 12013  information technology  Software            Software
# 12014  information technology  Software            Software
# 12015             health care       NaN  Support Activities
#
# [12016 rows x 11 columns]

# %% [markdown]
# ## Dictionary of phases

# %%
Design = df1.loc[df1['df1 Phases'] == 'Design','Skill_US'].tolist()
General = df1.loc[df1['df1 Phases'] == 'General Skills','Skill_US'].tolist()
Ideation = df1.loc[df1['df1 Phases'] == 'Ideation and Development','Skill_US'].tolist()
Materials = df1.loc[df1['df1 Phases'] == 'Materials','Skill_US'].tolist()
Production = df1.loc[df1['df1 Phases'] == 'Production and Assembling','Skill_US'].tolist()
Software = df1.loc[df1['df1 Phases'] == 'Software','Skill_US'].tolist()
Supply = df1.loc[df1['df1 Phases'] == 'Supply Chain and Logistics','Skill_US'].tolist()
Support = df1.loc[df1['df1 Phases'] == 'Support Activities','Skill_US'].tolist()
Tooling = df1.loc[df1['df1 Phases'] == 'Tooling and Machining','Skill_US'].tolist()

mydict = {'Design':Design,'General Skills':General,'Ideation and Development':Ideation,'Materials':Materials,'Production and Assembling':Production,'Software':Software,'Supply Chain and Logistics':Supply,'Support Activities':Support,'Tooling and Machining':Tooling,}
print(mydict)
# Out:
# {'Design': ['3d modeling / design', 'leadership in energy and environmental design (leed) rating system', 'advanced manufacturing plant design', 'color editing', 'wooden structure building', 'brush painting', 'floral design', 'typesetting', 'digital video workflow', 'freelance graphics', 'organize images', 'cinematography', 'computer-generated imagery (cgi)', 'transformer design', 'structural design', 'interior design', 'facility design', 'materials design', 'engineering design', 'highway design', 'project design', 'instructional program design', 'ux wireframes', 'foundation design', 'landscape design', 'microsoft publisher', 'adobe creative suite', 'structural steel design', 'planogram design', 'graphical user interface (gui)', 'poster design', 'paint blending', 'microsoft visio professional', 'corel photo-paint', 'immunoassay design', 'poetry', 'wacom tablet software', 'technical drawings', 'document design', 'corel photo', 'creative packaging', 'fine arts', 'maya', 'catia', 'design and construction', 'photo editing', 'steel forms', 'microsoft visio', 'user interface (ui) design', 'blood draws', 'book design', 'construction design', 'bridge design', 'civil 3d', 'gif animator', 'aerospace system design', 'drawing preparation', 'survey design', 'advanced composites', 'commercial interior design', 'interior painting', 'character design', 'spray painting', 'gaming industry knowledge', 'autocad', 'design software', 'roadway design', 'corporate design', '3d animation', 'video production', 'illustration', 'fixative', 'graphic design industry knowledge', 'linear editing', 'sculpting', 'sustainable design', 'pipeline design', 'rough sketches', 'graphics editing', 'vehicle component design', 'design refinement', 'adobe acrobat', 'set design', 'v-ray', 'instructional design principles', 'modern art', 'web typography', 'intersection design', 'digital circuit design', 'magazine design', 'creative design', 'architectural design', 'automotive design', '2d animation', 'page design', 'stop motion animation', 'component design', 'final sketches', 'vectoring', 'adobe indesign', '3d sketching', 'brochure design', 'timber design', 'cinema 4d', 'trial design', 'engineering design evaluation', 'microsoft powerpoint', 'graphics software', 'visual interdev', 'corel painter', 'musical instrument digital interface (midi)', 'gaming platforms', 'paint sprayer', 'interaction design', 'grass cutting', 'creative direction', 'paint shop pro', 'prezi', 'adobe aftereffects', 'design modification', 'interior architecture', 'concrete design', 'urban design', 'color blending', 'professional architect', 'animation', 'natural channel design', 'electrical design', 'technical illustration', 'component design improvement', 'steel design', 'design for environment', 'architectural standards', 'game development', 'zbrush', 'schematic design', 'civil engineering industry knowledge', 'cad / cam (computer-aided design / manufacturing)', 'adobe pagemaker', 'building design', 'style sheets', 'leadership in energy and environmental design (leed)', 'ama style guide', 'architectural practices', 'macromedia', 'hvac design', 'civil engineering principles', 'design industry knowledge', 'print design', 'storyboarding', 'design for reuse', 'pdf design', 'building electrical design', 'digital ic design', 'electromechanical design', 'instrument design', 'digital and analog design', 'line art', 'green design', 'analog design', 'architectural techniques', 'soffit', 'environmental graphic design', 'watercolor', 'copy editing', '3d conceptual design', 'presentation design', 'opengl', 'adobe illustrator', 'photovoltaic system design', 'process design', 'project layout', 'image editing', 'adobe freehand', 'final drawings', 'scale drawings', 'solar photovoltaic design', 'technical writing / editing', 'darkroom', 'press kit design', 'electronic component design', 'piping design', 'acrylic paint', 'sketching', 'equipment design', 'pcb layout and design', 'autodesk', 'preliminary sketches', 'mu ...

# %% [markdown]
# ## Service Bureaus (SBs)

# %%
SB = pandas.read_csv('D:/BG/Paper_2/analyses-2/SB/SB-Data.csv')
SB.columns
# Out:
# Index(['BGTJobId', 'JobDate', 'CleanTitle', 'CanonTitle', 'SOC', 'SOCName',
#        'ONET', 'ONETName', 'Employer', 'Sector', 'SectorName', 'NAICS3',
#        'NAICS4', 'NAICS5', 'NAICS6', 'City', 'County', 'State', 'Lat', 'Lon',
#        'Edu', 'MaxEdu', 'Degree', 'MaxDegree', 'Exp', 'MaxExp', 'MinSalary',
#        'MaxSalary', 'MinHrlySalary', 'MaxHrlySalary', 'PayFrequency',
#        'SalaryType', 'JobHours', 'SOC2', 'SOC4', 'SOC5', 'SK',
#        'Employer_clean', 'n_terms', 'SK_without', 'TECH', 'occupation',
#        'firm1', 'firm2', 'firm', 'plant', 'plant_5'],
#       dtype='object')

# %% [markdown]
# ## Calculating the number of terms in each phase for Service Bureaus (SB)

# %%
df2 = SB.copy()
df2.SK = df2.SK.str.split(',')
df2['Length'] = df2.SK.str.len()
df2 = df2[['BGTJobId','SK','TECH','occupation','Length']]
mylist = mydf[['BGTJobId','SK']].values.tolist()
print(mylist[0:5])
df3 = []
for job in mylist:
  for phase in mydict:
    c = 0
    for phrase in mydict[phase]:
      c = c + job[1].count(phrase)
    df3.append([job[0],phase,c])
df3 =  pandas.DataFrame(df3,columns=['BGTJobId','Phases','Count'])
df3 = df3.pivot(index='BGTJobId',columns='Phases',values='Count')
df3 = df3.merge(df2,left_on='BGTJobId',right_on='BGTJobId')
df3 = df3[['BGTJobId','SK','TECH','occupation']+list(mydict.keys())+['Length']]
df3
# Out:
# [[351932089, ['troubleshooting', 'verbal / oral communication', 'communication skills', 'problem solving', 'detail-oriented', 'mechanical engineering', 'legal compliance', 'civil engineering', 'design modification', 'writing', 'carpentry']], [352056182, ['machining', 'welding', 'industrial mechanic experience', 'mechanical maintenance', 'hydraulics', 'technical training', 'repair', 'carpentry']], [352057607, ['mechanical maintenance', 'carpentry']], [352058746, ['electrical devices', 'carpentry']], [352058822, ['budgeting', 'staff management', 'troubleshooting', 'verbal / oral communication', 'communication skills', 'writing', 'carpentry', 'civil engineering', 'design modification', 'problem solving', 'detail-oriented', 'mechanical engineering', 'legal compliance']]]
#           BGTJobId                                                 SK TECH  \
# 0        351932089  [troubleshooting, verbal / oral communication,...   TM
# 1        352056182  [machining, welding, industrial mechanic exper...   TM
# 2        352057607                [mechanical maintenance, carpentry]   TM
# 3        352058746                    [electrical devices, carpentry]   TM
# 4        352058822  [budgeting, staff management, troubleshooting,...   TM
# ...            ...                                                ...  ...
# 12440  38688610810  [sample preparation, quality assurance and con...   TM
# 12441  38688744068  [manufacturing processes, material requirement...   TM
# 12442  38689002966  [algebra, microsoft excel, manual dexterity, c...   AM
# 12443  38689119712  [international traffic in arms regulations (it...   TM
# 12444  38689223701  [inventory management, research, engineering m...   TM
#
#        occupation  Design  General Skills  Ideation and Development  \
# 0        Engineer       2               4                         0
# 1      Technician       0               0                         0
# 2        Engineer       0               0                         0
# 3      Technician       0               0                         0
# 4         Manager       2               4                         0
# ...           ...     ...             ...                       ...
# 12440    Operator       0               0                         0
# 12441     Manager       1               5                         0
# 12442    Operator       0               3                         0
# 12443  Technician       0               1                         0
# 12444    Engineer       0               3                         0
#
#        Materials  Production and Assembling  Software  \
# 0              0                          1         1
# 1              0                          2         0
# 2              0                          0         0
# 3              0                          0         0
# 4              0                          1         1
# ...          ...                        ...       ...
# 12440          1                          0         0
# 12441          0                          1         4
# 12442          0                          1         4
# 12443          1                          1         0
# 12444          1                          1         1
#
#        Supply Chain and Logistics  Support Activities  Tooling and Machining  \
# 0                               0                   2                      1
# 1                               0                   1                      5
# 2                               0                   0                      2
# 3                               0                   0                      2
# 4                               0                   4                      1
# ...                           ...                 ...                    ...
# 12440                           1                   4                      2
# 12441                           8                   7                      1
# 12442                           1                   1                      2
# 12443                           1                   0                      1
# 12444                           2                   9                      0
#
#        Length
# 0          11
# 1           8
# 2           2
# 3           2
# 4          13
# ...       ...
# 12440       8
# 12441      27
# 12442      12
# 12443       5
# 12444      17
#
# [12445 rows x 14 columns]

# %%
df4 = df3.copy()
for phase in list(mydict.keys()):
  df4.loc[df4[phase]>0,phase] = 1
df4['Phases-Sum'] = df4[list(mydict.keys())].sum(axis=1)
df4['Primary-Sum'] = df4[['Ideation and Development','Design','Materials','Tooling and Machining','Production and Assembling','Supply Chain and Logistics']].sum(axis=1)
df4
# Out:
#           BGTJobId                                                 SK TECH  \
# 0        351932089  [troubleshooting, verbal / oral communication,...   TM
# 1        352056182  [machining, welding, industrial mechanic exper...   TM
# 2        352057607                [mechanical maintenance, carpentry]   TM
# 3        352058746                    [electrical devices, carpentry]   TM
# 4        352058822  [budgeting, staff management, troubleshooting,...   TM
# ...            ...                                                ...  ...
# 12440  38688610810  [sample preparation, quality assurance and con...   TM
# 12441  38688744068  [manufacturing processes, material requirement...   TM
# 12442  38689002966  [algebra, microsoft excel, manual dexterity, c...   AM
# 12443  38689119712  [international traffic in arms regulations (it...   TM
# 12444  38689223701  [inventory management, research, engineering m...   TM
#
#        occupation  Design  General Skills  Ideation and Development  \
# 0        Engineer       1               1                         0
# 1      Technician       0               0                         0
# 2        Engineer       0               0                         0
# 3      Technician       0               0                         0
# 4         Manager       1               1                         0
# ...           ...     ...             ...                       ...
# 12440    Operator       0               0                         0
# 12441     Manager       1               1                         0
# 12442    Operator       0               1                         0
# 12443  Technician       0               1                         0
# 12444    Engineer       0               1                         0
#
#        Materials  Production and Assembling  Software  \
# 0              0                          1         1
# 1              0                          1         0
# 2              0                          0         0
# 3              0                          0         0
# 4              0                          1         1
# ...          ...                        ...       ...
# 12440          1                          0         0
# 12441          0                          1         1
# 12442          0                          1         1
# 12443          1                          1         0
# 12444          1                          1         1
#
#        Supply Chain and Logistics  Support Activities  Tooling and Machining  \
# 0                               0                   1                      1
# 1                               0                   1                      1
# 2                               0                   0                      1
# 3                               0                   0                      1
# 4                               0                   1                      1
# ...                           ...                 ...                    ...
# 12440                           1                   1                      1
# 12441                           1                   1                      1
# 12442                           1                   1                      1
# 12443                           1                   0                      1
# 12444                           1                   1                      0
#
#        Length  Phases-Sum  Primary-Sum
# 0          11           6            3
# 1           8           3            2
# 2           2           1            1
# 3           2           1            1
# 4          13           6            3
# ...       ...         ...          ...
# 12440       8           4            3
# 12441      27           7            4
# 12442      12           6            3
# 12443       5           5            4
# 12444      17           6            3
#
# [12445 rows x 16 columns]

# %%
fig = plt.figure(figsize=(10,10))
plt.barh(list(mydict.keys()),df4[list(mydict.keys())].sum(axis=0))
plt.title('Number of job postings in each activity')
plt.show()

# %% [markdown]
# ## Distribution of the number of primary activities per job posting

# %%
fig = plt.figure(figsize=(10,10))
plt.bar(df5.index.to_list(),df4.groupby(['Primary-Sum'])['BGTJobId'].count())
plt.xlabel('Number of primary activities per job posting')
plt.ylabel('Number of job postings')
plt.show()

# %% [markdown]
# ## Mean of the number of primary activities per job posting by technology and occupation

# %%
df4.groupby(['TECH','occupation'])['Primary-Sum'].mean().unstack('TECH').reindex(['Manager','Engineer','Technician','Operator'],axis=0)
# Out:
# TECH              AM        TM
# occupation
# Manager     2.489583  1.620690
# Engineer    3.662222  2.941486
# Technician  2.727273  2.414272
# Operator    2.679612  2.090778
